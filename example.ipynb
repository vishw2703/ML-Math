# %%
import numpy as np

# %%
! pip install Pillow as PIL
# Out:
# Requirement already satisfied: Pillow in c:\users\vishw\anaconda3\lib\site-packages (9.2.0)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

# %%
img = Image.open('example.jpg')
plt.imshow(img)

# %%
imggray = img.convert('LA')
plt.imshow(imggray)

# %%
imgmat = np.array(list(imggray.getdata(band=0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat)
plt.imshow(imgmat, cmap='gray')

# %%
U, sigma, V = np.linalg.svd(imgmat)

# %%
np.shape(U)
# Out:
# (720, 720)

# %%
reconstimg = np.matrix(U[:, :1])* np.diag(sigma[:1])* np.matrix(V[:1, :])
plt.imshow(reconstimg, cmap='gray')

# %%
for i in [2, 4, 8, 16, 32, 64, 128, 256, 512]:
    reconstimg  = np.matrix(U[:, :i])* np.diag(sigma[:i])* np.matrix(V[:i, :])
    plt.imshow(reconstimg, cmap='gray')
    title = "n = %s" % i
    plt.title(title)
    plt.show()

# %%
! pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vishw\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.8.0.74

# %%
import cv2
import numpy as np

image = cv2.imread('example.jpg')
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(image, -1, sharpen_kernel)

cv2.imshow('sharpen', sharpen)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Python\example.ipynb Cell 13 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/d%3A/Python/example.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a> sharpen = cv2.filter2D(image, -1, sharpen_kernel)
#       <a href='vscode-notebook-cell:/d%3A/Python/example.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a> cv2.imshow('sharpen', sharpen)
# ----> <a href='vscode-notebook-cell:/d%3A/Python/example.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a> cv2.waitKey()
#
# KeyboardInterrupt:
